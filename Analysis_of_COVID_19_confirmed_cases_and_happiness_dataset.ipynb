# %% [markdown]
# **Importing modoules**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print("modules are imported")
# Out:
# modules are imported
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# **1). Importing COVID -19 Conformed cases dataset**

# %%
from google.colab import files  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6cf5206c-9543-41f7-8c81-b46baed57eb2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6cf5206c-9543-41f7-8c81-b46baed57eb2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving covid19_Confirmed_dataset.csv to covid19_Confirmed_dataset.csv

# %%
corona_dataset_csv = pd.read_csv('covid19_Confirmed_dataset.csv')

# %%
corona_dataset_csv.head(15)
# Out:
#                   Province/State       Country/Region  ...  4/29/20  4/30/20
# 0                            NaN          Afghanistan  ...     1939     2171
# 1                            NaN              Albania  ...      766      773
# 2                            NaN              Algeria  ...     3848     4006
# 3                            NaN              Andorra  ...      743      745
# 4                            NaN               Angola  ...       27       27
# 5                            NaN  Antigua and Barbuda  ...       24       24
# 6                            NaN            Argentina  ...     4285     4428
# 7                            NaN              Armenia  ...     1932     2066
# 8   Australian Capital Territory            Australia  ...      106      106
# 9                New South Wales            Australia  ...     3016     3025
# 10            Northern Territory            Australia  ...       28       28
# ...

# %% [markdown]
# **1 a). check the shape of the dataframe**

# %%
corona_dataset_csv.shape
# Out:
# (266, 104)

# %% [markdown]
# **2). Delete the unwanted coloumns**

# %%
corona_dataset_csv.drop(["Lat","Long"], axis = 1, inplace = True)

# %%
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  ...  4/29/20  4/30/20
# 0                           NaN          Afghanistan  ...     1939     2171
# 1                           NaN              Albania  ...      766      773
# 2                           NaN              Algeria  ...     3848     4006
# 3                           NaN              Andorra  ...      743      745
# 4                           NaN               Angola  ...       27       27
# 5                           NaN  Antigua and Barbuda  ...       24       24
# 6                           NaN            Argentina  ...     4285     4428
# 7                           NaN              Armenia  ...     1932     2066
# 8  Australian Capital Territory            Australia  ...      106      106
# 9               New South Wales            Australia  ...     3016     3025
#
# [10 rows x 102 columns]

# %% [markdown]
# **2 a). Aggregating the rows by the country**

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  4/28/20  4/29/20  4/30/20
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1828     1939     2171
# Albania               0        0        0  ...      750      766      773
# Algeria               0        0        0  ...     3649     3848     4006
# Andorra               0        0        0  ...      743      743      745
# Angola                0        0        0  ...       27       27       27
#
# [5 rows x 100 columns]

# %%
corona_dataset_aggregated.shape
# Out:
# (187, 100)

# %% [markdown]
# **2 b). visualizing data related to a specific country**

# %%
corona_dataset_aggregated.loc["India"].plot()
corona_dataset_aggregated.loc["China"].plot()
corona_dataset_aggregated.loc["Spain"].plot()
plt.legend()

# %% [markdown]
# **3). Calculating a good measure**

# %%
corona_dataset_aggregated.loc["China"].plot()

# %%
corona_dataset_aggregated.loc["China"][:4].plot()

# %% [markdown]
# **3 a). Calculating and plotting the first derivative of the Curve**

# %%
corona_dataset_aggregated.loc["China"].diff().plot()

# %% [markdown]
# **3 b). Calculating the maximum infection rate for india,china and spain**

# %%
corona_dataset_aggregated.loc["India"].diff().max()
# Out:
# 1893.0

# %%
corona_dataset_aggregated.loc["China"].diff().max()
# Out:
# 15136.0

# %%
corona_dataset_aggregated.loc["Spain"].diff().max()
# Out:
# 9630.0

# %% [markdown]
# **3 c). Find the maximum infection rate for all the countries**

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for c in countries:
    max_infection_rates.append(corona_dataset_aggregated.loc[c].diff().max())
corona_dataset_aggregated["max_infection_rate"] = max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  4/29/20  4/30/20  max_infection_rate
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1939     2171               232.0
# Albania               0        0        0  ...      766      773                34.0
# Algeria               0        0        0  ...     3848     4006               199.0
# Andorra               0        0        0  ...      743      745                43.0
# Angola                0        0        0  ...       27       27                 5.0
#
# [5 rows x 101 columns]

# %% [markdown]
# **3 d). Create a new dataframe with only the required coloumn**

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated["max_infection_rate"])

# %%
corona_data.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %%
corona_data.head().plot()

# %% [markdown]
# **4).Importing the world happiness report**

# %% [markdown]
# **4 a). Importing the dataset**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-167fddab-6f9b-4c4a-9d4d-cdf30f807424" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-167fddab-6f9b-4c4a-9d4d-cdf30f807424">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving worldwide_happiness_report.csv to worldwide_happiness_report.csv

# %%
happiness_report_csv = pd.read_csv('worldwide_happiness_report.csv')

# %%
happiness_report_csv.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %% [markdown]
# **4 b). Drop the useless coloumns**

# %%
useless_cols = ["Overall rank","Score","Generosity","Perceptions of corruption"]

# %%
happiness_report_csv.drop(useless_cols,axis = 1,inplace = True)

# %%
happiness_report_csv.head()
# Out:
#   Country or region  ...  Freedom to make life choices
# 0           Finland  ...                         0.596
# 1           Denmark  ...                         0.592
# 2            Norway  ...                         0.603
# 3           Iceland  ...                         0.591
# 4       Netherlands  ...                         0.557
#
# [5 rows x 5 columns]

# %% [markdown]
# **4 c). Change the indices of the dataframe**

# %%
happiness_report_csv.set_index("Country or region",inplace = True)

# %%
happiness_report_csv.head()
# Out:
#                    GDP per capita  ...  Freedom to make life choices
# Country or region                  ...
# Finland                     1.340  ...                         0.596
# Denmark                     1.383  ...                         0.592
# Norway                      1.488  ...                         0.603
# Iceland                     1.380  ...                         0.591
# Netherlands                 1.396  ...                         0.557
#
# [5 rows x 4 columns]

# %% [markdown]
# **4 d). Join the Two Datasets that we made**

# %% [markdown]
# **Corona Dataset**

# %%
corona_data.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %%
corona_data.shape
# Out:
# (187, 1)

# %% [markdown]
# **World happiness report**

# %%
happiness_report_csv.head()
# Out:
#                    GDP per capita  ...  Freedom to make life choices
# Country or region                  ...
# Finland                     1.340  ...                         0.596
# Denmark                     1.383  ...                         0.592
# Norway                      1.488  ...                         0.603
# Iceland                     1.380  ...                         0.591
# Netherlands                 1.396  ...                         0.557
#
# [5 rows x 4 columns]

# %%
happiness_report_csv.shape
# Out:
# (156, 4)

# %%
data = corona_data.join(happiness_report_csv,how = "inner")

# %%
data
# Out:
#              max_infection_rate  ...  Freedom to make life choices
# Afghanistan               232.0  ...                         0.000
# Albania                    34.0  ...                         0.383
# Algeria                   199.0  ...                         0.086
# Argentina                 291.0  ...                         0.471
# Armenia                   134.0  ...                         0.283
# ...                         ...  ...                           ...
# Venezuela                  29.0  ...                         0.154
# Vietnam                    19.0  ...                         0.543
# Yemen                       5.0  ...                         0.143
# Zambia                      9.0  ...                         0.431
# Zimbabwe                    8.0  ...                         0.361
#
# [143 rows x 5 columns]

# %% [markdown]
# **4 e). Correlation matrix**

# %%
data.corr()
# Out:
#                               max_infection_rate  ...  Freedom to make life choices
# max_infection_rate                      1.000000  ...                      0.078196
# GDP per capita                          0.250118  ...                      0.394603
# Social support                          0.191958  ...                      0.456246
# Healthy life expectancy                 0.289263  ...                      0.427892
# Freedom to make life choices            0.078196  ...                      1.000000
#
# [5 rows x 5 columns]

# %% [markdown]
# **5) Visualization of the results**

# %%
data.head()
# Out:
#              max_infection_rate  ...  Freedom to make life choices
# Afghanistan               232.0  ...                         0.000
# Albania                    34.0  ...                         0.383
# Algeria                   199.0  ...                         0.086
# Argentina                 291.0  ...                         0.471
# Armenia                   134.0  ...                         0.283
#
# [5 rows x 5 columns]

# %% [markdown]
# **5 a). Plotting GDP vs maximum infection rate**

# %%
x = data["GDP per capita"]
y = data["max_infection_rate"]
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# **5 b). Plotting of Social Support vs maximum infection rate**

# %%
x = data["Social support"]
y = data["max_infection_rate"]
sns.scatterplot(x,y)

# %%
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# **5 c). Plotting of health life expectancy and max infection rate**

# %%
x = data["Healthy life expectancy"]
y = data["max_infection_rate"]
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# **5 d). Freedom to make life choices vs max infection rate**

# %%
x = data["Freedom to make life choices"]
y = data["max_infection_rate"]
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))
